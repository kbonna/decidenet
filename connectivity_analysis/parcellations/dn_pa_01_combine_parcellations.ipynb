# %% [markdown]
# # Combine parcellations
#
# Here, two parcellations are combined into one. These parcellations are:
# - base parcellation: whole-brain network functional parcellation from [Power et al., 2011](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3222858/)
# - meta-analytic parcellation: only regions involved in processing positive and negative prediction errors from [Fouragnan et al., 2018](https://pubmed.ncbi.nlm.nih.gov/29575249/)
#
# There are three main strategies for combining individual ROIs:
#
# ![strategy](parcellation_combine_strategy.png)

# %%
import os

import pandas as pd

from os.path import join
from pathlib import Path
from dn_utils.path import path_derivatives, path_parcellations

# %%
path_root = os.environ.get('DECIDENET_PATH')
path_derivatives = join(path_root, 'data/main_fmri_study/derivatives')
path_parcellations = join(path_derivatives, 'parcellations')

df_roi_base = pd.read_csv(
    join(path_parcellations, 'Power_roi/Power_roi_table.csv'))
df_roi_meta = pd.read_csv(
    join(path_parcellations, 'meta_roi_4and5/meta_roi_table.csv'))

# %%
df_roi_meta.head()
# Out:
#   abbrev                          name hemisphere   x   y   z  cluster_size  \
# 0   dMCC  Dorsomedial cingulate cortex          R   2  24  36         12712
# 1   aINS               Anterior insula          R  32  24  -2          6120
# 2   aINS               Anterior insula          L -32  22  -4          4880
# 3    PAL                      Pallidum          R  12   8   4          3360
# 4    PAL                      Pallidum          L -14   6   2          2520
#
#    ale_score   netName  approxRadius  radius(mm)
# 0      0.051  perr_dec     14.477995           5
# 1      0.062  perr_dec     11.347171           5
# 2      0.056  perr_dec     10.522293           5
# 3      0.040  perr_dec      9.291451           4
# 4      0.029  perr_dec      8.441844           4

# %%
df_roi_new = df_roi_base.copy()
df_roi_new['origNetName'] = df_roi_new['netName']
df_roi_new['strategy'] = None
df_roi_new['origName'] = None

shared_columns = ['x', 'y', 'z', 'netName', 'radius(mm)']

for i, roi_meta in df_roi_meta.iterrows():

    roi_meta_name = roi_meta['abbrev'] + '_' + roi_meta['hemisphere']
    
    # Calculate distance between meta ROI and all ROIs from base atlas
    dist = df_roi_base.loc[:, ['x', 'y', 'z']] - roi_meta[['x', 'y', 'z']]
    dist = dist.pow(2).sum(axis=1).pow(0.5)

    # Grab closest region
    roi_base_idx = dist.argmin()
    roi_base = df_roi_base.loc[roi_base_idx]
    
    # Max radius of newly created ROI (non-overlapping)
    max_r = dist[roi_base_idx] - roi_base['radius(mm)']

    print(f'ROI: {roi_meta_name} ({roi_meta["netName"]})\n\t' + \
          f'• closest roi: {roi_base_idx} ({roi_base["netName"]}, r={roi_base["radius(mm)"]}mm)\n\t' + \
          f'• distance = {dist[roi_base_idx]:4.2f}mm, max_r={max_r:4.2f}mm')
    
    if max_r >= 5:
        # Create new ROI
        df_roi_new = df_roi_new.append(roi_meta[shared_columns], 
                                       ignore_index=True)
        df_roi_new.iloc[-1, df_roi_new.columns.get_loc('strategy')] = 'created'
        df_roi_new.iloc[-1, df_roi_new.columns.get_loc('origName')] = roi_meta_name
        
        print(f'\t✅ created new ROI: {roi_meta_name} ({roi_meta["netName"]})\n')
    
    elif max_r > 0:
        # Shift old ROI and rename network
        df_roi_new.loc[roi_base_idx, shared_columns] = roi_meta[shared_columns]
        df_roi_new.loc[roi_base_idx, 'strategy'] = 'shifted'
        df_roi_new.loc[roi_base_idx, 'origName'] = roi_meta_name
        
        before_xyz = roi_base[['x', 'y', 'z']].astype(str).str.cat(sep=', ')
        after_xyz = roi_meta[['x', 'y', 'z']].astype(str).str.cat(sep=', ')
        
        print(f'\t✅ shifted: ({before_xyz}) ⮕ ({after_xyz})')
        print(f'\t✅ relabelled: {roi_base["netName"]} ⮕ {roi_meta["netName"]}\n')
    
    else:
        # Just change network label
        df_roi_new.loc[roi_base_idx, 'netName'] = roi_meta['netName']
        df_roi_new.loc[roi_base_idx, 'strategy'] = 'relabelled'
        df_roi_new.loc[roi_base_idx, 'origName'] = roi_meta_name
        
        print(f'\t✅ relabelled: {roi_base["netName"]} ⮕ {roi_meta["netName"]}\n')
# Out:
# ROI: dMCC_R (perr_dec)
# 	• closest roi: 215 (salience, r=5mm)
# 	• distance = 3.32mm, max_r=-1.68mm
# 	✅ relabelled: salience ⮕ perr_dec
#
# ROI: aINS_R (perr_dec)
# 	• closest roi: 208 (salience, r=5mm)
# 	• distance = 6.71mm, max_r=1.71mm
# 	✅ shifted: (36, 22, 3) ⮕ (32, 24, -2)
# 	✅ relabelled: salience ⮕ perr_dec
#
# ROI: aINS_L (perr_dec)
# 	• closest roi: 207 (salience, r=5mm)
# 	• distance = 5.39mm, max_r=0.39mm
# 	✅ shifted: (-35, 20, 0) ⮕ (-32, 22, -4)
# 	✅ relabelled: salience ⮕ perr_dec
#
# ROI: PAL_R (perr_dec)
# 	• closest roi: 232 (subcortical, r=5mm)
# 	• distance = 5.20mm, max_r=0.20mm
# 	✅ shifted: (15, 5, 7) ⮕ (12, 8, 4)
# 	✅ relabelled: subcortical ⮕ perr_dec
#
# ROI: PAL_L (perr_dec)
# 	• closest roi: 227 (subcortical, r=5mm)
# 	• distance = 6.40mm, max_r=1.40mm
# 	✅ shifted: (-15, 4, 8) ⮕ (-14, 6, 2)
# 	✅ relabelled: subcortical ⮕ perr_dec
#
# ROI: mFG1_R (perr_dec)
# 	• closest roi: 185 (fronto_parietal, r=5mm)
# 	• distance = 10.86mm, max_r=5.86mm
# 	✅ created new ROI: mFG1_R (perr_dec)
#
# ROI: mFG2_R (perr_dec)
# 	• closest roi: 192 (fronto_parietal, r=5mm)
# 	• distance = 4.47mm, max_r=-0.53mm
# 	✅ relabelled: fronto_parietal ⮕ perr_dec
#
# ROI: mFG_L (perr_dec)
# 	• closest roi: 177 (fronto_parietal, r=5mm)
# 	• distance = 6.48mm, max_r=1.48mm
# 	✅ shifted: (-23, 11, 64) ⮕ (-28, 12, 60)
# 	✅ relabelled: fronto_parietal ⮕ perr_dec
#
# ROI: IPL_R (perr_dec)
# 	• closest roi: 191 (fronto_parietal, r=5mm)
# 	• distance = 8.12mm, max_r=3.12mm
# 	✅ shifted: (44, -53, 47) ⮕ (40, -48, 42)
# 	✅ relabelled: fronto_parietal ⮕ perr_dec
#
# ROI: IPL_L (perr_dec)
# 	• closest roi: 258 (dorsal_attention, r=5mm)
# 	• distance = 7.35mm, max_r=2.35mm
# 	✅ shifted: (-33, -46, 47) ⮕ (-38, -48, 42)
# 	✅ relabelled: dorsal_attention ⮕ perr_dec
#
# ROI: mTG_R (perr_dec)
# 	• closest roi: 118 (default_mode, r=5mm)
# 	• distance = 6.56mm, max_r=1.56mm
# 	✅ shifted: (65, -31, -9) ⮕ (60, -28, -6)
# 	✅ relabelled: default_mode ⮕ perr_dec
#
# ROI: AMYG_R (perr_dec)
# 	• closest roi: 233 (subcortical, r=5mm)
# 	• distance = 20.22mm, max_r=15.22mm
# 	✅ created new ROI: AMYG_R (perr_dec)
#
# ROI: THA1_L (perr_dec)
# 	• closest roi: 223 (subcortical, r=5mm)
# 	• distance = 7.00mm, max_r=2.00mm
# 	✅ shifted: (-10, -18, 7) ⮕ (-12, -12, 10)
# 	✅ relabelled: subcortical ⮕ perr_dec
#
# ROI: THA2_L (perr_dec)
# 	• closest roi: 223 (subcortical, r=5mm)
# 	• distance = 9.00mm, max_r=4.00mm
# 	✅ shifted: (-10, -18, 7) ⮕ (-6, -26, 8)
# 	✅ relabelled: subcortical ⮕ perr_dec
#
# ROI: HAB_R (perr_dec)
# 	• closest roi: 6 (uncertain, r=5mm)
# 	• distance = 17.03mm, max_r=12.03mm
# 	✅ created new ROI: HAB_R (perr_dec)
#
# ROI: dlPFC_L (perr_dec)
# 	• closest roi: 200 (fronto_parietal, r=5mm)
# 	• distance = 4.12mm, max_r=-0.88mm
# 	✅ relabelled: fronto_parietal ⮕ perr_dec
#
# ROI: dlPFC_R (perr_dec)
# 	• closest roi: 205 (salience, r=5mm)
# 	• distance = 9.90mm, max_r=4.90mm
# 	✅ shifted: (31, 33, 26) ⮕ (40, 34, 30)
# 	✅ relabelled: salience ⮕ perr_dec
#
# ROI: FUS_L (perr_dec)
# 	• closest roi: 261 (dorsal_attention, r=5mm)
# 	• distance = 3.00mm, max_r=-2.00mm
# 	✅ relabelled: dorsal_attention ⮕ perr_dec
#
# ROI: PREC_L (perr_dec)
# 	• closest roi: 41 (somatomotor, r=5mm)
# 	• distance = 11.45mm, max_r=6.45mm
# 	✅ created new ROI: PREC_L (perr_dec)
#
# ROI: dmOFC_R (perr_dec)
# 	• closest roi: 199 (fronto_parietal, r=5mm)
# 	• distance = 10.30mm, max_r=5.30mm
# 	✅ created new ROI: dmOFC_R (perr_dec)
#
# ROI: dmPFC_R (perr_dec)
# 	• closest roi: 107 (default_mode, r=5mm)
# 	• distance = 11.75mm, max_r=6.75mm
# 	✅ created new ROI: dmPFC_R (perr_dec)
#
# ROI: STS_R (perr_dec)
# 	• closest roi: 234 (ventral_attention, r=5mm)
# 	• distance = 4.12mm, max_r=-0.88mm
# 	✅ relabelled: ventral_attention ⮕ perr_dec
#
# ROI: vSTR_L (perr_inc)
# 	• closest roi: 226 (subcortical, r=5mm)
# 	• distance = 10.10mm, max_r=5.10mm
# 	✅ created new ROI: vSTR_L (perr_inc)
#
# ROI: vSTR_R (perr_inc)
# 	• closest roi: 232 (subcortical, r=5mm)
# 	• distance = 11.79mm, max_r=6.79mm
# 	✅ created new ROI: vSTR_R (perr_inc)
#
# ROI: vmPFC_L (perr_inc)
# 	• closest roi: 108 (default_mode, r=5mm)
# 	• distance = 9.27mm, max_r=4.27mm
# 	✅ shifted: (-3, 44, -9) ⮕ (-2, 42, 0)
# 	✅ relabelled: default_mode ⮕ perr_inc
#
# ROI: PCC_L (perr_inc)
# 	• closest roi: 132 (memory, r=5mm)
# 	• distance = 6.16mm, max_r=1.16mm
# 	✅ shifted: (-2, -35, 31) ⮕ (0, -32, 36)
# 	✅ relabelled: memory ⮕ perr_inc
#
# ROI: PCC_L (perr_inc)
# 	• closest roi: 132 (memory, r=5mm)
# 	• distance = 5.48mm, max_r=0.48mm
# 	✅ shifted: (-2, -35, 31) ⮕ (0, -36, 26)
# 	✅ relabelled: memory ⮕ perr_inc
#
# ROI: vlOFC_R (perr_inc)
# 	• closest roi: 11 (uncertain, r=5mm)
# 	• distance = 6.63mm, max_r=1.63mm
# 	✅ shifted: (34, 38, -12) ⮕ (32, 44, -10)
# 	✅ relabelled: uncertain ⮕ perr_inc
#
# ROI: dmPFC_L (perr_inc)
# 	• closest roi: 89 (default_mode, r=5mm)
# 	• distance = 5.39mm, max_r=0.39mm
# 	✅ shifted: (-11, -56, 16) ⮕ (-6, -56, 14)
# 	✅ relabelled: default_mode ⮕ perr_inc
#
# ROI: mPFC_L (perr_inc)
# 	• closest roi: 112 (default_mode, r=5mm)
# 	• distance = 5.74mm, max_r=0.74mm
# 	✅ shifted: (-3, 42, 16) ⮕ (-2, 46, 20)
# 	✅ relabelled: default_mode ⮕ perr_inc

# %%
df_roi_new.loc[df_roi_new['netName'] == 'perr_inc']
# Out:
#       x   y   z  netCode netColor   netName  radius(mm)   origNetName  \
# 11   32  44 -10     -1.0    White  perr_inc           5     uncertain
# 89   -6 -56  14      5.0      Red  perr_inc           5  default_mode
# 108  -2  42   0      5.0      Red  perr_inc           5  default_mode
# 112  -2  46  20      5.0      Red  perr_inc           5  default_mode
# 132   0 -36  26      6.0     Gray  perr_inc           5        memory
# 270 -12   8  -4      NaN      NaN  perr_inc           4           NaN
# 271   8   8  -2      NaN      NaN  perr_inc           4           NaN
#
#     strategy origName
# 11   shifted  vlOFC_R
# 89   shifted  dmPFC_L
# 108  shifted  vmPFC_L
# 112  shifted   mPFC_L
# 132  shifted    PCC_L
# 270  created   vSTR_L
# 271  created   vSTR_R

# %%
df_roi_new.loc[df_roi_new['netName'] == 'perr_dec']
# Out:
#       x   y   z  netCode netColor   netName  radius(mm)        origNetName  \
# 118  60 -28  -6      5.0      Red  perr_dec           5       default_mode
# 177 -28  12  60      8.0   Yellow  perr_dec           5    fronto_parietal
# 191  40 -48  42      8.0   Yellow  perr_dec           5    fronto_parietal
# 192  32  14  56      8.0   Yellow  perr_dec           5    fronto_parietal
# 200 -42  25  30      8.0   Yellow  perr_dec           5    fronto_parietal
# 205  40  34  30      9.0    Black  perr_dec           5           salience
# 207 -32  22  -4      9.0    Black  perr_dec           5           salience
# 208  32  24  -2      9.0    Black  perr_dec           5           salience
# 215   5  23  37      9.0    Black  perr_dec           5           salience
# 223  -6 -26   8     10.0    Brown  perr_dec           5        subcortical
# 227 -14   6   2     10.0    Brown  perr_dec           4        subcortical
# 232  12   8   4     10.0    Brown  perr_dec           4        subcortical
# 234  54 -43  22     11.0     Teal  perr_dec           5  ventral_attention
# 258 -38 -48  42     12.0    Green  perr_dec           5   dorsal_attention
# 261 -42 -60  -9     12.0    Green  perr_dec           5   dorsal_attention
# 264  38   4  32      NaN      NaN  perr_dec           5                NaN
# 265  18  -6 -12      NaN      NaN  perr_dec           5                NaN
# 266   2 -20 -18      NaN      NaN  perr_dec           5                NaN
# 267 -52   0  34      NaN      NaN  perr_dec           5                NaN
# 268  38  58  -2      NaN      NaN  perr_dec           5                NaN
# 269  20  50   4      NaN      NaN  perr_dec           5                NaN
#
#        strategy origName
# 118     shifted    mTG_R
# 177     shifted    mFG_L
# 191     shifted    IPL_R
# 192  relabelled   mFG2_R
# 200  relabelled  dlPFC_L
# 205     shifted  dlPFC_R
# 207     shifted   aINS_L
# 208     shifted   aINS_R
# 215  relabelled   dMCC_R
# 223     shifted   THA2_L
# 227     shifted    PAL_L
# 232     shifted    PAL_R
# 234  relabelled    STS_R
# 258     shifted    IPL_L
# 261  relabelled    FUS_L
# 264     created   mFG1_R
# 265     created   AMYG_R
# 266     created    HAB_R
# 267     created   PREC_L
# 268     created  dmOFC_R
# 269     created  dmPFC_R

# %%
path_out = join(path_parcellations, 'combined_roi_4and5')
Path(path_out).mkdir(exist_ok=True)

df_roi_new = df_roi_new.sort_values(by='netName', axis=0, ascending=False)
df_roi_new.to_csv(join(path_out, 'combined_roi_4and5_table.csv'), index=False)

# For thesis
df_roi_new.loc[~df_roi_new['strategy'].isna()].to_csv(
    join(path_out, "combined_roi_4and5_new_rois_table.csv"), index=False)

# %%
df_roi_new
# Out:
#       x   y   z  netCode netColor   netName  radius(mm) origNetName strategy  \
# 160  42 -66  -8      7.0     Blue    visual           5      visual     None
# 168  37 -84  13      7.0     Blue    visual           5      visual     None
# 167 -40 -88  -6      7.0     Blue    visual           5      visual     None
# 152  43 -78 -12      7.0     Blue    visual           5      visual     None
# 153 -47 -76 -10      7.0     Blue    visual           5      visual     None
# ..   ..  ..  ..      ...      ...       ...         ...         ...      ...
# 69  -55  -9  12      4.0     Pink  auditory           5    auditory     None
# 72  -30 -27  12      4.0     Pink  auditory           5    auditory     None
# 71   59 -17  29      4.0     Pink  auditory           5    auditory     None
# 66   43 -23  20      4.0     Pink  auditory           5    auditory     None
# 67  -50 -34  26      4.0     Pink  auditory           5    auditory     None
#
#     origName
# 160     None
# 168     None
# 167     None
# 152     None
# 153     None
# ..       ...
# 69      None
# 72      None
# 71      None
# 66      None
# 67      None
#
# [272 rows x 10 columns]
